# %%
import sys
sys.path.append("../") # go to parent dir

import re

from s2v_dqn.graph_type import GraphType
from s2v_dqn.interaction import train
from s2v_dqn.utils import replay_graphs

# %load_ext autoreload
# %autoreload 2

# %%
PROBLEM = 'TSP'

# %%
tsp_base_params = {
    # 'embedding_layers': 5,
    'embedding_layers': 4,
    'nstep': 1,
#     'lr_config': [[0, 1e-3], [0.5, 1e-4], [0.75, 1e-5]],
    'lr_config': [[0, 1e-3], [0.75, 1e-4]],
    'eps_start': 1.00,
    'eps_end': 0.01,
    'eps_end_at_episode': 1.0,
    'n_episodes': 1500,
    'validate_each': 100,
    'validate_at_start': True,
    'print_train_metrics_each': 10,
    'batch_size': 64,
    'exact_solution_max_size': 18,
    'graph_type': GraphType.EUCLIDEAN,
    'graph_params': {'max_coord': 1e6, 'k_nearest': 10},
    'discount_factor': 0.1,
    'warmup_steps': 1000,
    'update_params_each': 1,
    'target_update': 'soft',
    'double_dqn': True,
    'tau': 5e-3,
}

# %%
# %%time
params = {
    **tsp_base_params,
    'n_vertices': 10,
}
experiment_idx = 1
n_runs = 10
agents_1 = train(n_runs, params, PROBLEM, experiment_idx)
# Out:
# {'problem': 'tsp', 'embedding_layers': 4, 'nstep': 1, 'lr_config': [[0, 0.001], [0.75, 0.0001]], 'eps_start': 1.0, 'eps_end': 0.01, 'eps_end_at_episode': 1.0, 'n_episodes': 1500, 'validate_each': 100, 'validate_at_start': True, 'print_train_metrics_each': 10, 'batch_size': 64, 'exact_solution_max_size': 18, 'graph_type': <GraphType.EUCLIDEAN: 1>, 'graph_params': {'max_coord': 1000000.0, 'k_nearest': 10}, 'discount_factor': 0.1, 'warmup_steps': 1000, 'update_params_each': 1, 'target_update': 'soft', 'double_dqn': True, 'tau': 0.005, 'n_vertices': 10}
# Starting run #1/10...
# Starting run #2/10...
# Starting run #3/10...
# Starting run #4/10...
# Starting run #5/10...
# Starting run #6/10...
# Starting run #7/10...
# Starting run #8/10...
# Starting run #9/10...
# Starting run #10/10...
# Min of avg validation score across episodes: 1.0339071166899367
# CPU times: user 2h 39s, sys: 9.12 s, total: 2h 48s
# Wall time: 18min 52s

# %%
# %%time
params = {
    **tsp_base_params,
    'n_vertices': 10,
    'env_extra_params': {'positive_reward': True},
    'lr_config': [[0, 1e-3], [0.75, 1e-4]],
}
experiment_idx = 2
n_runs = 10
agents_2 = train(n_runs, params, PROBLEM, experiment_idx)
# Out:
# {'problem': 'tsp', 'embedding_layers': 4, 'nstep': 1, 'lr_config': [[0, 0.001], [0.75, 0.0001]], 'eps_start': 1.0, 'eps_end': 0.01, 'eps_end_at_episode': 1.0, 'n_episodes': 1500, 'validate_each': 100, 'validate_at_start': True, 'print_train_metrics_each': 10, 'batch_size': 64, 'exact_solution_max_size': 18, 'graph_type': <GraphType.EUCLIDEAN: 1>, 'graph_params': {'max_coord': 1000000.0, 'k_nearest': 10}, 'discount_factor': 0.1, 'warmup_steps': 1000, 'update_params_each': 1, 'target_update': 'soft', 'double_dqn': True, 'tau': 0.005, 'n_vertices': 10, 'env_extra_params': {'positive_reward': True}}
# Starting run #1/10...
# Starting run #2/10...
# Starting run #3/10...
# Starting run #4/10...
# Starting run #5/10...
# Starting run #6/10...
# Starting run #7/10...
# Starting run #8/10...
# Starting run #9/10...
# Starting run #10/10...
# Min of avg validation score across episodes: 1.0042737293311192
# CPU times: user 2h 1min 54s, sys: 8.16 s, total: 2h 2min 2s
# Wall time: 19min 24s

# %%
# %%time
params = {
    **tsp_base_params,
    'n_vertices': 15,
}
experiment_idx = 3
n_runs = 10
agents_3 = train(n_runs, params, PROBLEM, experiment_idx)
# Out:
# {'problem': 'tsp', 'embedding_layers': 4, 'nstep': 1, 'lr_config': [[0, 0.001], [0.75, 0.0001]], 'eps_start': 1.0, 'eps_end': 0.01, 'eps_end_at_episode': 1.0, 'n_episodes': 1500, 'validate_each': 100, 'validate_at_start': True, 'print_train_metrics_each': 10, 'batch_size': 64, 'exact_solution_max_size': 18, 'graph_type': <GraphType.EUCLIDEAN: 1>, 'graph_params': {'max_coord': 1000000.0, 'k_nearest': 10}, 'discount_factor': 0.1, 'warmup_steps': 1000, 'update_params_each': 1, 'target_update': 'soft', 'double_dqn': True, 'tau': 0.005, 'n_vertices': 15}
# Starting run #1/10...
# Starting run #2/10...
# Starting run #3/10...
# Starting run #4/10...
# Starting run #5/10...
# Starting run #6/10...
# Starting run #7/10...
# Starting run #8/10...
# Starting run #9/10...
# Starting run #10/10...
# Min of avg validation score across episodes: 1.0259192709777512
# CPU times: user 4h 14min 41s, sys: 41.7 s, total: 4h 15min 22s
# Wall time: 1h 9min 6s

# %%
# %%time
params = {
    **tsp_base_params,
    'n_vertices': 15,
    'env_extra_params': {'positive_reward': True},
    'lr_config': [[0, 1e-3], [0.75, 1e-4]],
}
experiment_idx = 4
n_runs = 10
agents_4 = train(n_runs, params, PROBLEM, experiment_idx)
# Out:
# {'problem': 'tsp', 'embedding_layers': 4, 'nstep': 1, 'lr_config': [[0, 0.001], [0.75, 0.0001]], 'eps_start': 1.0, 'eps_end': 0.01, 'eps_end_at_episode': 1.0, 'n_episodes': 1500, 'validate_each': 100, 'validate_at_start': True, 'print_train_metrics_each': 10, 'batch_size': 64, 'exact_solution_max_size': 18, 'graph_type': <GraphType.EUCLIDEAN: 1>, 'graph_params': {'max_coord': 1000000.0, 'k_nearest': 10}, 'discount_factor': 0.1, 'warmup_steps': 1000, 'update_params_each': 1, 'target_update': 'soft', 'double_dqn': True, 'tau': 0.005, 'n_vertices': 15, 'env_extra_params': {'positive_reward': True}}
# Starting run #1/10...
# Starting run #2/10...
# Starting run #3/10...
# Starting run #4/10...
# Starting run #5/10...
# Starting run #6/10...
# Starting run #7/10...
# Starting run #8/10...
# Starting run #9/10...
# Starting run #10/10...
# Min of avg validation score across episodes: 1.0077752533264523
# CPU times: user 4h 17min 24s, sys: 28.6 s, total: 4h 17min 53s
# ...

# %%
# %%time
params = {
    **tsp_base_params,
    'n_vertices': 20,
}
experiment_idx = 5
n_runs = 10
agents_5 = train(n_runs, params, PROBLEM, experiment_idx)
# Out:
# {'problem': 'tsp', 'embedding_layers': 4, 'nstep': 1, 'lr_config': [[0, 0.001], [0.75, 0.0001]], 'eps_start': 1.0, 'eps_end': 0.01, 'eps_end_at_episode': 1.0, 'n_episodes': 1500, 'validate_each': 100, 'validate_at_start': True, 'print_train_metrics_each': 10, 'batch_size': 64, 'exact_solution_max_size': 18, 'graph_type': <GraphType.EUCLIDEAN: 1>, 'graph_params': {'max_coord': 1000000.0, 'k_nearest': 10}, 'discount_factor': 0.1, 'warmup_steps': 1000, 'update_params_each': 1, 'target_update': 'soft', 'double_dqn': True, 'tau': 0.005, 'n_vertices': 20}
# Starting run #1/10...
# Starting run #2/10...
# Starting run #3/10...
# Starting run #4/10...
# Starting run #5/10...
# Starting run #6/10...
# Starting run #7/10...
# Starting run #8/10...
# Starting run #9/10...
# Starting run #10/10...
# Min of avg validation score across episodes: 1.0458475610093232
# CPU times: user 5h 11min 41s, sys: 22.1 s, total: 5h 12min 3s
# Wall time: 46min 21s

# %%
# %%time
params = {
    **tsp_base_params,
    'n_vertices': 20,
    'env_extra_params': {'positive_reward': True},
    'lr_config': [[0, 1e-3], [0.75, 1e-4]],
}
experiment_idx = 6
n_runs = 10
agents_6 = train(n_runs, params, PROBLEM, experiment_idx)
# Out:
# {'problem': 'tsp', 'embedding_layers': 4, 'nstep': 1, 'lr_config': [[0, 0.001], [0.75, 0.0001]], 'eps_start': 1.0, 'eps_end': 0.01, 'eps_end_at_episode': 1.0, 'n_episodes': 1500, 'validate_each': 100, 'validate_at_start': True, 'print_train_metrics_each': 10, 'batch_size': 64, 'exact_solution_max_size': 18, 'graph_type': <GraphType.EUCLIDEAN: 1>, 'graph_params': {'max_coord': 1000000.0, 'k_nearest': 10}, 'discount_factor': 0.1, 'warmup_steps': 1000, 'update_params_each': 1, 'target_update': 'soft', 'double_dqn': True, 'tau': 0.005, 'n_vertices': 20, 'env_extra_params': {'positive_reward': True}}
# Starting run #1/10...
# Starting run #2/10...
# Starting run #3/10...
# Starting run #4/10...
# Starting run #5/10...
# Starting run #6/10...
# Starting run #7/10...
# Starting run #8/10...
# Starting run #9/10...
# Starting run #10/10...
# Min of avg validation score across episodes: 1.0060839574499636
# CPU times: user 5h 16min 16s, sys: 23.3 s, total: 5h 16min 39s
# Wall time: 46min 55s

# %%
# %%time
params = {
    **tsp_base_params,
    'n_vertices': 25,
}
experiment_idx = 7
n_runs = 10
agents_7 = train(n_runs, params, PROBLEM, experiment_idx)
# Out:
# {'problem': 'tsp', 'embedding_layers': 4, 'nstep': 1, 'lr_config': [[0, 0.001], [0.75, 0.0001]], 'eps_start': 1.0, 'eps_end': 0.01, 'eps_end_at_episode': 1.0, 'n_episodes': 1500, 'validate_each': 100, 'validate_at_start': True, 'print_train_metrics_each': 10, 'batch_size': 64, 'exact_solution_max_size': 18, 'graph_type': <GraphType.EUCLIDEAN: 1>, 'graph_params': {'max_coord': 1000000.0, 'k_nearest': 10}, 'discount_factor': 0.1, 'warmup_steps': 1000, 'update_params_each': 1, 'target_update': 'soft', 'double_dqn': True, 'tau': 0.005, 'n_vertices': 25}
# Starting run #1/10...
# Starting run #2/10...
# Starting run #3/10...
# Starting run #4/10...
# Starting run #5/10...
# Starting run #6/10...
# Starting run #7/10...
# Starting run #8/10...
# Starting run #9/10...
# Starting run #10/10...
# Min of avg validation score across episodes: 1.0771894487109617
# CPU times: user 6h 10min 22s, sys: 18.7 s, total: 6h 10min 41s
# Wall time: 51min 31s

# %%
# %%time
params = {
    **tsp_base_params,
    'n_vertices': 25,
    'env_extra_params': {'positive_reward': True},
    'lr_config': [[0, 1e-3], [0.75, 1e-4]],
}
experiment_idx = 8
n_runs = 10
agents_8 = train(n_runs, params, PROBLEM, experiment_idx)
# Out:
# {'problem': 'tsp', 'embedding_layers': 4, 'nstep': 1, 'lr_config': [[0, 0.001], [0.75, 0.0001]], 'eps_start': 1.0, 'eps_end': 0.01, 'eps_end_at_episode': 1.0, 'n_episodes': 1500, 'validate_each': 100, 'validate_at_start': True, 'print_train_metrics_each': 10, 'batch_size': 64, 'exact_solution_max_size': 18, 'graph_type': <GraphType.EUCLIDEAN: 1>, 'graph_params': {'max_coord': 1000000.0, 'k_nearest': 10}, 'discount_factor': 0.1, 'warmup_steps': 1000, 'update_params_each': 1, 'target_update': 'soft', 'double_dqn': True, 'tau': 0.005, 'n_vertices': 25, 'env_extra_params': {'positive_reward': True}}
# Starting run #1/10...
# Starting run #2/10...
# Starting run #3/10...
# Starting run #4/10...
# Starting run #5/10...
# Starting run #6/10...
# Starting run #7/10...
# Starting run #8/10...
# Starting run #9/10...
# Starting run #10/10...
# Min of avg validation score across episodes: 1.0117939496145025
# CPU times: user 6h 9min 13s, sys: 17.1 s, total: 6h 9min 30s
# Wall time: 51min 12s

# %%
# %%time
params = {
    **tsp_base_params,
    'n_vertices': 40,
}
experiment_idx = 9
n_runs = 10
agents_9 = train(n_runs, params, PROBLEM, experiment_idx)
# Out:
# {'problem': 'tsp', 'embedding_layers': 4, 'nstep': 1, 'lr_config': [[0, 0.001], [0.75, 0.0001]], 'eps_start': 1.0, 'eps_end': 0.01, 'eps_end_at_episode': 1.0, 'n_episodes': 1500, 'validate_each': 100, 'validate_at_start': True, 'print_train_metrics_each': 10, 'batch_size': 64, 'exact_solution_max_size': 18, 'graph_type': <GraphType.EUCLIDEAN: 1>, 'graph_params': {'max_coord': 1000000.0, 'k_nearest': 10}, 'discount_factor': 0.1, 'warmup_steps': 1000, 'update_params_each': 1, 'target_update': 'soft', 'double_dqn': True, 'tau': 0.005, 'n_vertices': 40}
# Starting run #1/10...
# Training interrupted in episode #390
# Starting run #2/10...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# ~/dev/ufrj/msc/tese/tsp/s2v_dqn/interaction.py in train(n_runs, params, problem, experiment_idx)
#     352         print(f'Starting run #{run_idx+1}/{n_runs}...')
# ...

# %%
# %%time
params = {
    **tsp_base_params,
    'n_vertices': 40,
    'env_extra_params': {'positive_reward': True},
    'lr_config': [[0, 1e-3], [0.75, 1e-4]],
}
experiment_idx = 10
n_runs = 10
agents_10 = train(n_runs, params, PROBLEM, experiment_idx)
# Out:
# {'problem': 'tsp', 'embedding_layers': 4, 'nstep': 1, 'lr_config': [[0, 0.001], [0.75, 0.0001]], 'eps_start': 1.0, 'eps_end': 0.01, 'eps_end_at_episode': 1.0, 'n_episodes': 1500, 'validate_each': 100, 'validate_at_start': True, 'print_train_metrics_each': 10, 'batch_size': 64, 'exact_solution_max_size': 18, 'graph_type': <GraphType.EUCLIDEAN: 1>, 'graph_params': {'max_coord': 1000000.0, 'k_nearest': 10}, 'discount_factor': 0.1, 'warmup_steps': 1000, 'update_params_each': 1, 'target_update': 'soft', 'double_dqn': True, 'tau': 0.005, 'n_vertices': 40, 'env_extra_params': {'positive_reward': True}}
# Starting run #1/10...
# Starting run #2/10...
# Starting run #3/10...
# Starting run #4/10...
# Starting run #5/10...
# Starting run #6/10...
# Starting run #7/10...
# Starting run #8/10...
# Starting run #9/10...
# Starting run #10/10...
# Min of avg validation score across episodes: 0.9737575354416406
# CPU times: user 12h 46min 33s, sys: 55.4 s, total: 12h 47min 28s
# ...

# %%
# %%time
params = {
    **tsp_base_params,
    'n_vertices': 60,
    'env_extra_params': {'positive_reward': True},
    'lr_config': [[0, 1e-3], [0.75, 1e-4]],
}
experiment_idx = 11
n_runs = 10
agents_10 = train(n_runs, params, PROBLEM, experiment_idx)
# Out:
# {'problem': 'tsp', 'embedding_layers': 4, 'nstep': 1, 'lr_config': [[0, 0.001], [0.75, 0.0001]], 'eps_start': 1.0, 'eps_end': 0.01, 'eps_end_at_episode': 1.0, 'n_episodes': 1500, 'validate_each': 100, 'validate_at_start': True, 'print_train_metrics_each': 10, 'batch_size': 64, 'exact_solution_max_size': 18, 'graph_type': <GraphType.EUCLIDEAN: 1>, 'graph_params': {'max_coord': 1000000.0, 'k_nearest': 10}, 'discount_factor': 0.1, 'warmup_steps': 1000, 'update_params_each': 1, 'target_update': 'soft', 'double_dqn': True, 'tau': 0.005, 'n_vertices': 60, 'env_extra_params': {'positive_reward': True}}
# Starting run #1/10...
# Starting run #2/10...
# Starting run #3/10...
# Starting run #4/10...
# Starting run #5/10...
# Starting run #6/10...
# Starting run #7/10...
# Starting run #8/10...
# Starting run #9/10...
# Starting run #10/10...
# Min of avg validation score across episodes: 0.9594389749161246
# CPU times: user 1d 30min 31s, sys: 2min 56s, total: 1d 33min 28s
# ...

# %%
# %%time

# rerun with greater solver time cutoff
params = {
    **tsp_base_params,
    'n_vertices': 40,
    'env_extra_params': {'positive_reward': True},
    'lr_config': [[0, 1e-3], [0.75, 1e-4]],
}
experiment_idx = 12
n_runs = 10
agents_12 = train(n_runs, params, PROBLEM, experiment_idx)
# Out:
# {'problem': 'tsp', 'embedding_layers': 4, 'nstep': 1, 'lr_config': [[0, 0.001], [0.75, 0.0001]], 'eps_start': 1.0, 'eps_end': 0.01, 'eps_end_at_episode': 1.0, 'n_episodes': 1500, 'validate_each': 100, 'validate_at_start': True, 'print_train_metrics_each': 10, 'batch_size': 64, 'exact_solution_max_size': 18, 'graph_type': <GraphType.EUCLIDEAN: 1>, 'graph_params': {'max_coord': 1000000.0, 'k_nearest': 10}, 'discount_factor': 0.1, 'warmup_steps': 1000, 'update_params_each': 1, 'target_update': 'soft', 'double_dqn': True, 'tau': 0.005, 'n_vertices': 40, 'env_extra_params': {'positive_reward': True}}
# Starting run #1/10...
# approximation_ratio=1.175533423337475
# approximation_ratio=1.1314823586428762
# approximation_ratio=1.1833289406057488
# approximation_ratio=1.0950807103316582
# approximation_ratio=1.094407951499389
# approximation_ratio=1.0781408547403304
# approximation_ratio=1.1707137915172598
# approximation_ratio=1.2185008742915464
# approximation_ratio=1.1738746601048233
# ...

# %%
# %%time

# rerun with greater solver time cutoff
params = {
    **tsp_base_params,
    'n_vertices': 60,
    'env_extra_params': {'positive_reward': True},
    'lr_config': [[0, 1e-3], [0.75, 1e-4]],
}
experiment_idx = 13
n_runs = 10
agents_13 = train(n_runs, params, PROBLEM, experiment_idx)
# Out:
# {'problem': 'tsp', 'embedding_layers': 4, 'nstep': 1, 'lr_config': [[0, 0.001], [0.75, 0.0001]], 'eps_start': 1.0, 'eps_end': 0.01, 'eps_end_at_episode': 1.0, 'n_episodes': 1500, 'validate_each': 100, 'validate_at_start': True, 'print_train_metrics_each': 10, 'batch_size': 64, 'exact_solution_max_size': 18, 'graph_type': <GraphType.EUCLIDEAN: 1>, 'graph_params': {'max_coord': 1000000.0, 'k_nearest': 10}, 'discount_factor': 0.1, 'warmup_steps': 1000, 'update_params_each': 1, 'target_update': 'soft', 'double_dqn': True, 'tau': 0.005, 'n_vertices': 60, 'env_extra_params': {'positive_reward': True}}
# Starting run #1/10...
# approximation_ratio=1.2535033145192669
# approximation_ratio=1.1317020048206736
# approximation_ratio=1.2270545631913938
# approximation_ratio=1.1608216334897477
# approximation_ratio=1.256466764070774
# approximation_ratio=1.1653552768253785
# approximation_ratio=1.251632780712028
# approximation_ratio=1.1423592827712674
# approximation_ratio=1.2161687126124876
# ...

# %%
# %%time

# rerun with greater solver time cutoff
params = {
    **tsp_base_params,
    'n_vertices': 25,
    'env_extra_params': {'positive_reward': True},
    'lr_config': [[0, 1e-3], [0.75, 1e-4]],
    'tensorboard_log': True
}
experiment_idx = 14
n_runs = 1
agents_14 = train(n_runs, params, PROBLEM, experiment_idx)
# Out:
# {'problem': 'tsp', 'embedding_layers': 4, 'nstep': 1, 'lr_config': [[0, 0.001], [0.75, 0.0001]], 'eps_start': 1.0, 'eps_end': 0.01, 'eps_end_at_episode': 1.0, 'n_episodes': 1500, 'validate_each': 100, 'validate_at_start': True, 'print_train_metrics_each': 10, 'batch_size': 64, 'exact_solution_max_size': 18, 'graph_type': <GraphType.EUCLIDEAN: 1>, 'graph_params': {'max_coord': 1000000.0, 'k_nearest': 10}, 'discount_factor': 0.1, 'warmup_steps': 1000, 'update_params_each': 1, 'target_update': 'soft', 'double_dqn': True, 'tau': 0.005, 'n_vertices': 25, 'env_extra_params': {'positive_reward': True}, 'tensorboard_log': True}
# Starting run #1/1...
# log_path='../logs/tsp/fit/exp_14_0'
# Min of avg validation score across episodes: 1.0264215121620643
# CPU times: user 46min 35s, sys: 8.2 s, total: 46min 44s
# Wall time: 7min 57s

# %%
# %%time

# rerun with greater solver time cutoff
params = {
    **tsp_base_params,
    'n_vertices': 15,
    'env_extra_params': {'positive_reward': True},
    'lr_config': [[0, 1e-3], [0.75, 1e-4]],
    'tensorboard_log': True
}
experiment_idx = 15
n_runs = 1
agents_15 = train(n_runs, params, PROBLEM, experiment_idx)
# Out:
# {'problem': 'tsp', 'embedding_layers': 4, 'nstep': 1, 'lr_config': [[0, 0.001], [0.75, 0.0001]], 'eps_start': 1.0, 'eps_end': 0.01, 'eps_end_at_episode': 1.0, 'n_episodes': 1500, 'validate_each': 100, 'validate_at_start': True, 'print_train_metrics_each': 10, 'batch_size': 64, 'exact_solution_max_size': 18, 'graph_type': <GraphType.EUCLIDEAN: 1>, 'graph_params': {'max_coord': 1000000.0, 'k_nearest': 10}, 'discount_factor': 0.1, 'warmup_steps': 1000, 'update_params_each': 1, 'target_update': 'soft', 'double_dqn': True, 'tau': 0.005, 'n_vertices': 15, 'env_extra_params': {'positive_reward': True}, 'tensorboard_log': True}
# Starting run #1/1...
# log_path='../logs/tsp/fit/exp_15_0'
# Min of avg validation score across episodes: 1.0012732178569936
# CPU times: user 31min 11s, sys: 9.65 s, total: 31min 21s
# Wall time: 9min 10s

# %%
# %%time
params = {
    **tsp_base_params,
    'graph_type': GraphType.EUCLIDEAN,
    'n_vertices': 15,
}
experiment_idx = 1
n_runs = 3
agents = train(n_runs, params, PROBLEM, experiment_idx)
# Out:
# {'problem': 'tsp', 'embedding_layers': 5, 'nstep': 2, 'lr_config': [[0, 0.001], [0.5, 0.0001], [0.75, 1e-05]], 'eps_start': 1.0, 'eps_end': 0.0, 'eps_end_at_episode': 1.0, 'n_episodes': 5000, 'validate_each': 100, 'print_train_metrics_each': 10, 'batch_size': 64, 'exact_solution_max_size': 20, 'graph_params': {'max_coord': 1000000.0}, 'graph_type': <GraphType.EUCLIDEAN: 1>, 'n_vertices': 15}
# Starting run #1/3...
# Starting run #2/3...
# Starting run #3/3...
# Min of avg validation score across episodes: 1.6582611155111433
# CPU times: user 3h 37min 43s, sys: 29 s, total: 3h 38min 12s
# Wall time: 1h 2min 8s

# %%
# %%time
params = {
    **tsp_base_params,
    'graph_type': GraphType.EUCLIDEAN,
    'n_vertices': 10,
}
experiment_idx = 2
n_runs = 3
agents_2 = train(n_runs, params, PROBLEM, experiment_idx)
# Out:
# {'problem': 'tsp', 'embedding_layers': 5, 'nstep': 2, 'lr_config': [[0, 0.001], [0.5, 0.0001], [0.75, 1e-05]], 'eps_start': 1.0, 'eps_end': 0.0, 'eps_end_at_episode': 1.0, 'n_episodes': 5000, 'validate_each': 100, 'print_train_metrics_each': 10, 'batch_size': 64, 'exact_solution_max_size': 20, 'graph_params': {'max_coord': 1000000.0}, 'graph_type': <GraphType.EUCLIDEAN: 1>, 'n_vertices': 10}
# Starting run #1/3...
# Starting run #2/3...
# Starting run #3/3...
# Min of avg validation score across episodes: 1.0913485902598739
# CPU times: user 1h 57min 31s, sys: 4.44 s, total: 1h 57min 36s
# Wall time: 20min 5s

# %%
# %%time
params = {
    **tsp_base_params,
    'graph_type': GraphType.EUCLIDEAN,
    'n_vertices': 10,
    'n_episodes': 5000,
}
experiment_idx = 3
n_runs = 3
agents_3 = train(n_runs, params, PROBLEM, experiment_idx)
# Out:
# {'problem': 'tsp', 'embedding_layers': 5, 'nstep': 2, 'lr_config': [[0, 0.001], [0.5, 0.0001], [0.75, 1e-05]], 'eps_start': 1.0, 'eps_end': 0.0, 'eps_end_at_episode': 1.0, 'n_episodes': 5000, 'validate_each': 100, 'print_train_metrics_each': 10, 'batch_size': 64, 'exact_solution_max_size': 20, 'graph_params': {'max_coord': 1000000.0, 'k_nearest': 10}, 'graph_type': <GraphType.EUCLIDEAN: 1>, 'n_vertices': 10}
# Starting run #1/3...
# Starting run #2/3...
# Starting run #3/3...
# Min of avg validation score across episodes: 1.241090220404019
# CPU times: user 1h 35min 40s, sys: 3.55 s, total: 1h 35min 43s
# Wall time: 13min 36s

# %%
# %%time
params = {
    **tsp_base_params,
    'graph_type': GraphType.EUCLIDEAN,
    'n_vertices': 10,
    'n_episodes': 5000,
}
experiment_idx = 4
n_runs = 3
agents_4 = train(n_runs, params, PROBLEM, experiment_idx)
# Out:
# {'problem': 'tsp', 'embedding_layers': 5, 'nstep': 2, 'lr_config': [[0, 0.001], [0.5, 0.0001], [0.75, 1e-05]], 'eps_start': 1.0, 'eps_end': 0.0, 'eps_end_at_episode': 1.0, 'n_episodes': 5000, 'validate_each': 100, 'print_train_metrics_each': 10, 'batch_size': 64, 'exact_solution_max_size': 20, 'graph_params': {'max_coord': 1000000.0, 'k_nearest': 10}, 'graph_type': <GraphType.EUCLIDEAN: 1>, 'n_vertices': 10}
# Starting run #1/3...
# Starting run #2/3...
# Starting run #3/3...
# Min of avg validation score across episodes: 1.1492949158374322
# CPU times: user 1h 35min 54s, sys: 3.92 s, total: 1h 35min 58s
# Wall time: 13min 36s

# %%
# %%time
params = {
    **tsp_base_params,
    'graph_type': GraphType.EUCLIDEAN,
    'n_vertices': 10,
    'n_episodes': 5000,
}
experiment_idx = 5
n_runs = 3
agents_5 = train(n_runs, params, PROBLEM, experiment_idx)
# Out:
# {'problem': 'tsp', 'embedding_layers': 3, 'nstep': 2, 'lr_config': [[0, 0.001], [0.5, 0.0001], [0.75, 1e-05]], 'eps_start': 1.0, 'eps_end': 0.0, 'eps_end_at_episode': 1.0, 'n_episodes': 5000, 'validate_each': 100, 'print_train_metrics_each': 10, 'batch_size': 64, 'exact_solution_max_size': 20, 'graph_params': {'max_coord': 1000000.0, 'k_nearest': 10}, 'graph_type': <GraphType.EUCLIDEAN: 1>, 'n_vertices': 10}
# Starting run #1/3...
# Starting run #2/3...
# Starting run #3/3...
# Min of avg validation score across episodes: 1.049867116756455
# CPU times: user 1h 21min 34s, sys: 3.09 s, total: 1h 21min 37s
# Wall time: 11min 1s

# %%
# %%time
params = {
    **tsp_base_params,
    'graph_type': GraphType.EUCLIDEAN,
    'n_vertices': 10,
    'n_episodes': 2000,
}
experiment_idx = 6
n_runs = 3
print(1)
agents_6 = train(n_runs, params, PROBLEM, experiment_idx)
# Out:
# 1
# {'problem': 'tsp', 'embedding_layers': 3, 'nstep': 2, 'lr_config': [[0, 0.001], [0.5, 0.0001], [0.75, 1e-05]], 'eps_start': 1.0, 'eps_end': 0.0, 'eps_end_at_episode': 1.0, 'n_episodes': 2000, 'validate_each': 100, 'print_train_metrics_each': 10, 'batch_size': 64, 'exact_solution_max_size': 20, 'graph_params': {'max_coord': 1000000.0, 'k_nearest': 10}, 'discount_factor': 0.1, 'graph_type': <GraphType.EUCLIDEAN: 1>, 'n_vertices': 10}
# Starting run #1/3...
# 2
# Starting run #2/3...
# 2
# Starting run #3/3...
# 2
# Min of avg validation score across episodes: 1.3610575034212717
# CPU times: user 35min 30s, sys: 1.36 s, total: 35min 32s
# Wall time: 4min 47s

# %%
# %%time
params = {
    **tsp_base_params,
    'graph_type': GraphType.EUCLIDEAN,
    'n_vertices': 10,
    'n_episodes': 5000,
}
experiment_idx = 7
n_runs = 3
agents_7 = train(n_runs, params, PROBLEM, experiment_idx)
# Out:
# {'problem': 'tsp', 'embedding_layers': 3, 'nstep': 2, 'lr_config': [[0, 0.001], [0.5, 0.0001], [0.75, 1e-05]], 'eps_start': 1.0, 'eps_end': 0.0, 'eps_end_at_episode': 1.0, 'n_episodes': 5000, 'validate_each': 100, 'print_train_metrics_each': 10, 'batch_size': 64, 'exact_solution_max_size': 20, 'graph_params': {'max_coord': 1000000.0, 'k_nearest': 10}, 'discount_factor': 0.1, 'graph_type': <GraphType.EUCLIDEAN: 1>, 'n_vertices': 10}
# Starting run #1/3...
# 2
# Starting run #2/3...
# 2
# Starting run #3/3...
# 2
# Min of avg validation score across episodes: 1.4219984117148707
# CPU times: user 1h 33min 44s, sys: 2.86 s, total: 1h 33min 47s
# Wall time: 12min 25s

# %%
replay_graphs('tsp', 7, 0.1)
# Out:
# config_parsed="{'problem': 'tsp', 'embedding_layers': 3, 'nstep': 2, 'lr_config': [[0, 0.001], [0.5, 0.0001], [0.75, 1e-05]], 'eps_start': 1.0, 'eps_end': 0.0, 'eps_end_at_episode': 1.0, 'n_episodes': 5000, 'validate_each': 100, 'print_train_metrics_each': 10, 'batch_size': 64, 'exact_solution_max_size': 20, 'graph_params': {'max_coord': 1000000.0, 'k_nearest': 10}, 'discount_factor': 0.1, 'graph_type': 1, 'n_vertices': 10}"
# Min of avg validation score across episodes: 1.4219984117148707

# %%
# %%time
params = {
    **tsp_base_params,
    'graph_type': GraphType.EUCLIDEAN,
    'n_vertices': 10,
    'n_episodes': 5000,
    'nstep': 1
}
experiment_idx = 8
n_runs = 3
agents_8 = train(n_runs, params, PROBLEM, experiment_idx)
# Out:
# {'problem': 'tsp', 'embedding_layers': 3, 'nstep': 1, 'lr_config': [[0, 0.001], [0.5, 0.0001], [0.75, 1e-05]], 'eps_start': 1.0, 'eps_end': 0.0, 'eps_end_at_episode': 1.0, 'n_episodes': 5000, 'validate_each': 100, 'print_train_metrics_each': 10, 'batch_size': 64, 'exact_solution_max_size': 20, 'graph_params': {'max_coord': 1000000.0, 'k_nearest': 10}, 'discount_factor': 0.1, 'graph_type': <GraphType.EUCLIDEAN: 1>, 'n_vertices': 10}
# Starting run #1/3...
# 2
# Starting run #2/3...
# 2
# Starting run #3/3...
# 2
# Min of avg validation score across episodes: 1.1203748881411588
# CPU times: user 1h 34min 2s, sys: 3.07 s, total: 1h 34min 5s
# Wall time: 12min 30s

# %%
# %%time
params = {
    **tsp_base_params,
    'graph_type': GraphType.EUCLIDEAN,
    'n_vertices': 10,
    'n_episodes': 5000,
    'nstep': 1
}
experiment_idx = 9
n_runs = 3
agents_9 = train(n_runs, params, PROBLEM, experiment_idx)
# Out:
# {'problem': 'tsp', 'embedding_layers': 3, 'nstep': 1, 'lr_config': [[0, 0.001], [0.5, 0.0001], [0.75, 1e-05]], 'eps_start': 1.0, 'eps_end': 0.0, 'eps_end_at_episode': 1.0, 'n_episodes': 5000, 'validate_each': 100, 'print_train_metrics_each': 10, 'batch_size': 64, 'exact_solution_max_size': 20, 'graph_params': {'max_coord': 1000000.0, 'k_nearest': 10}, 'discount_factor': 0.1, 'graph_type': <GraphType.EUCLIDEAN: 1>, 'n_vertices': 10}
# Starting run #1/3...
# Starting run #2/3...
# Starting run #3/3...
# Min of avg validation score across episodes: 1.11476872453313
# CPU times: user 27min 44s, sys: 1.62 s, total: 27min 46s
# Wall time: 4min 52s

# %%
# %%time
params = {
    **tsp_base_params,
    'graph_type': GraphType.EUCLIDEAN,
    'n_vertices': 10,
    'n_episodes': 5000,
    'nstep': 1
}
experiment_idx = 10
n_runs = 3
agents_10 = train(n_runs, params, PROBLEM, experiment_idx)
# Out:
# {'problem': 'tsp', 'embedding_layers': 3, 'nstep': 1, 'lr_config': [[0, 0.001], [0.5, 0.0001], [0.75, 1e-05]], 'eps_start': 1.0, 'eps_end': 0.0, 'eps_end_at_episode': 1.0, 'n_episodes': 5000, 'validate_each': 100, 'print_train_metrics_each': 10, 'batch_size': 64, 'exact_solution_max_size': 20, 'graph_params': {'max_coord': 1000000.0, 'k_nearest': 10}, 'discount_factor': 0.1, 'graph_type': <GraphType.EUCLIDEAN: 1>, 'n_vertices': 10}
# Starting run #1/3...
# Starting run #2/3...
# Starting run #3/3...
# Min of avg validation score across episodes: 1.146987991906611
# CPU times: user 27min 39s, sys: 1.61 s, total: 27min 40s
# Wall time: 4min 52s

# %%
agents_10[0].update_t_step
# Out:
# 45000

# %%
# %%time
params = {
    **tsp_base_params,
    'graph_type': GraphType.EUCLIDEAN,
    'n_vertices': 10,
    'n_episodes': 5000,
    'nstep': 1
}
experiment_idx = 11
n_runs = 3
agents_11 = train(n_runs, params, PROBLEM, experiment_idx)
# Out:
# {'problem': 'tsp', 'embedding_layers': 3, 'nstep': 1, 'lr_config': [[0, 0.001], [0.5, 0.0001], [0.75, 1e-05]], 'eps_start': 1.0, 'eps_end': 0.0, 'eps_end_at_episode': 1.0, 'n_episodes': 5000, 'validate_each': 100, 'print_train_metrics_each': 10, 'batch_size': 64, 'exact_solution_max_size': 20, 'graph_params': {'max_coord': 1000000.0, 'k_nearest': 10}, 'discount_factor': 0.1, 'graph_type': <GraphType.EUCLIDEAN: 1>, 'n_vertices': 10}
# Starting run #1/3...
# Starting run #2/3...
# Starting run #3/3...
# Min of avg validation score across episodes: 1.2027537110164712
# CPU times: user 27min 27s, sys: 1.52 s, total: 27min 28s
# Wall time: 4min 57s

# %%
# %%time
params = {
    **tsp_base_params,
    'graph_type': GraphType.EUCLIDEAN,
    'n_vertices': 10,
    'n_episodes': 5000,
    'eps_start': 1.00,
    'eps_end': 0.05,
    'eps_end_at_episode': 0.9,
    'nstep': 1
}
experiment_idx = 12
n_runs = 3
agents_12 = train(n_runs, params, PROBLEM, experiment_idx)
# Out:
# {'problem': 'tsp', 'embedding_layers': 3, 'nstep': 1, 'lr_config': [[0, 0.001], [0.5, 0.0001], [0.75, 1e-05]], 'eps_start': 1.0, 'eps_end': 0.05, 'eps_end_at_episode': 0.9, 'n_episodes': 5000, 'validate_each': 100, 'print_train_metrics_each': 10, 'batch_size': 64, 'exact_solution_max_size': 20, 'graph_params': {'max_coord': 1000000.0, 'k_nearest': 10}, 'discount_factor': 0.1, 'graph_type': <GraphType.EUCLIDEAN: 1>, 'n_vertices': 10}
# Starting run #1/3...
# Starting run #2/3...
# Starting run #3/3...
# Min of avg validation score across episodes: 1.1636595315793703
# CPU times: user 27min, sys: 1.2 s, total: 27min 1s
# Wall time: 4min 45s

# %%
# %%time
params = {
    **tsp_base_params,
    'graph_type': GraphType.EUCLIDEAN,
    'n_vertices': 10,
    'n_episodes': 5000,
    'eps_start': 1.00,
    'eps_end': 0.05,
    'eps_end_at_episode': 0.9,
    'nstep': 1
}
experiment_idx = 13
n_runs = 3
agents_13 = train(n_runs, params, PROBLEM, experiment_idx)
# Out:
# {'problem': 'tsp', 'embedding_layers': 3, 'nstep': 1, 'lr_config': [[0, 0.001], [0.5, 0.0001], [0.75, 1e-05]], 'eps_start': 1.0, 'eps_end': 0.05, 'eps_end_at_episode': 0.9, 'n_episodes': 5000, 'validate_each': 100, 'print_train_metrics_each': 10, 'batch_size': 64, 'exact_solution_max_size': 20, 'graph_params': {'max_coord': 1000000.0, 'k_nearest': 10}, 'discount_factor': 0.1, 'graph_type': <GraphType.EUCLIDEAN: 1>, 'n_vertices': 10}
# Starting run #1/3...
# Starting run #2/3...
# Starting run #3/3...
# Min of avg validation score across episodes: 1.0719377702316648
# CPU times: user 1h 37min 33s, sys: 13.8 s, total: 1h 37min 47s
# Wall time: 13min 16s

# %%
replay_graphs('tsp', 13, max_loss=0.01)
# Out:
# config_parsed="{'problem': 'tsp', 'embedding_layers': 3, 'nstep': 1, 'lr_config': [[0, 0.001], [0.5, 0.0001], [0.75, 1e-05]], 'eps_start': 1.0, 'eps_end': 0.05, 'eps_end_at_episode': 0.9, 'n_episodes': 5000, 'validate_each': 100, 'print_train_metrics_each': 10, 'batch_size': 64, 'exact_solution_max_size': 20, 'graph_params': {'max_coord': 1000000.0, 'k_nearest': 10}, 'discount_factor': 0.1, 'graph_type': 1, 'n_vertices': 10}"
# Min of avg validation score across episodes: 1.0719377702316648

# %%
# %%time
params = {
    **tsp_base_params,
    'graph_type': GraphType.EUCLIDEAN,
    'n_vertices': 10,
    'n_episodes': 5000,
    'eps_start': 1.00,
    'eps_end': 0.05,
    'eps_end_at_episode': 0.9,
    'nstep': 1
}
experiment_idx = 14
n_runs = 3
agents_14 = train(n_runs, params, PROBLEM, experiment_idx)
# Out:
# {'problem': 'tsp', 'embedding_layers': 3, 'nstep': 1, 'lr_config': [[0, 0.001], [0.5, 0.0001], [0.75, 1e-05]], 'eps_start': 1.0, 'eps_end': 0.05, 'eps_end_at_episode': 0.9, 'n_episodes': 5000, 'validate_each': 100, 'print_train_metrics_each': 10, 'batch_size': 64, 'exact_solution_max_size': 20, 'graph_params': {'max_coord': 1000000.0, 'k_nearest': 10}, 'discount_factor': 0.1, 'graph_type': <GraphType.EUCLIDEAN: 1>, 'n_vertices': 10}
# Starting run #1/3...
# Starting run #2/3...
# Starting run #3/3...
# Min of avg validation score across episodes: 1.155544843730347
# CPU times: user 1h 27min 56s, sys: 3.56 s, total: 1h 27min 59s
# Wall time: 12min

# %%
# %%time
params = {
    **tsp_base_params,
    'graph_type': GraphType.EUCLIDEAN,
    'n_vertices': 10,
    'n_episodes': 5000,
    'eps_start': 1.00,
    'eps_end': 0.05,
    'eps_end_at_episode': 0.9,
    'nstep': 1,
    'env_extra_params': {'add_node_anywhere': True},
}
experiment_idx = 15
n_runs = 3
agents_15 = train(n_runs, params, PROBLEM, experiment_idx)
# Out:
# {'problem': 'tsp', 'embedding_layers': 3, 'nstep': 1, 'lr_config': [[0, 0.001], [0.5, 0.0001], [0.75, 1e-05]], 'eps_start': 1.0, 'eps_end': 0.05, 'eps_end_at_episode': 0.9, 'n_episodes': 5000, 'validate_each': 100, 'print_train_metrics_each': 10, 'batch_size': 64, 'exact_solution_max_size': 20, 'graph_params': {'max_coord': 1000000.0, 'k_nearest': 10}, 'discount_factor': 0.1, 'graph_type': <GraphType.EUCLIDEAN: 1>, 'n_vertices': 10, 'env_extra_params': {'add_node_anywhere': True}}
# Starting run #1/3...
# Starting run #2/3...
# Starting run #3/3...
# Min of avg validation score across episodes: 1.022842999744421
# CPU times: user 1h 31min 43s, sys: 2.92 s, total: 1h 31min 46s
# Wall time: 12min 31s

# %%
replay_graphs('tsp', 15, max_loss=0.02)
# Out:
# config_parsed="{'problem': 'tsp', 'embedding_layers': 3, 'nstep': 1, 'lr_config': [[0, 0.001], [0.5, 0.0001], [0.75, 1e-05]], 'eps_start': 1.0, 'eps_end': 0.05, 'eps_end_at_episode': 0.9, 'n_episodes': 5000, 'validate_each': 100, 'print_train_metrics_each': 10, 'batch_size': 64, 'exact_solution_max_size': 20, 'graph_params': {'max_coord': 1000000.0, 'k_nearest': 10}, 'discount_factor': 0.1, 'graph_type': 1, 'n_vertices': 10, 'env_extra_params': {'add_node_anywhere': True}}"
# Min of avg validation score across episodes: 1.022842999744421

# %%
# %%time
params = {
    **tsp_base_params,
    'graph_type': GraphType.EUCLIDEAN,
    'n_vertices': 15,
    'n_episodes': 5000,
    'eps_start': 1.00,
    'eps_end': 0.05,
    'eps_end_at_episode': 0.9,
    'nstep': 1,
    'env_extra_params': {'add_node_anywhere': True},
}
experiment_idx = 16
n_runs = 3
agents_16 = train(n_runs, params, PROBLEM, experiment_idx)
# Out:
# {'problem': 'tsp', 'embedding_layers': 3, 'nstep': 1, 'lr_config': [[0, 0.001], [0.5, 0.0001], [0.75, 1e-05]], 'eps_start': 1.0, 'eps_end': 0.05, 'eps_end_at_episode': 0.9, 'n_episodes': 5000, 'validate_each': 100, 'print_train_metrics_each': 10, 'batch_size': 64, 'exact_solution_max_size': 20, 'graph_params': {'max_coord': 1000000.0, 'k_nearest': 10}, 'discount_factor': 0.1, 'graph_type': <GraphType.EUCLIDEAN: 1>, 'n_vertices': 15, 'env_extra_params': {'add_node_anywhere': True}}
# Starting run #1/3...
# Starting run #2/3...
# Starting run #3/3...
# Min of avg validation score across episodes: 1.056164776177294
# CPU times: user 3h 3min 38s, sys: 36.1 s, total: 3h 4min 15s
# Wall time: 56min

# %%
replay_graphs('tsp', 16, max_loss=0.02)
# Out:
# config_parsed="{'problem': 'tsp', 'embedding_layers': 3, 'nstep': 1, 'lr_config': [[0, 0.001], [0.5, 0.0001], [0.75, 1e-05]], 'eps_start': 1.0, 'eps_end': 0.05, 'eps_end_at_episode': 0.9, 'n_episodes': 5000, 'validate_each': 100, 'print_train_metrics_each': 10, 'batch_size': 64, 'exact_solution_max_size': 20, 'graph_params': {'max_coord': 1000000.0, 'k_nearest': 10}, 'discount_factor': 0.1, 'graph_type': 1, 'n_vertices': 15, 'env_extra_params': {'add_node_anywhere': True}}"
# Min of avg validation score across episodes: 1.056164776177294

# %%
46+103+26+48
# Out:
# 223

# %%
# %%time
params = {
    **tsp_base_params,
    'graph_type': GraphType.EUCLIDEAN,
    'n_vertices': 13,
    'n_episodes': 1000,
    'eps_start': 1.00,
    'eps_end': 0.05,
    'eps_end_at_episode': 0.9,
    'nstep': 1,
    'env_extra_params': {'add_node_anywhere': True},
    'lr_config': [[0, 1e-3], [0.7, 1e-4], [0.9, 1e-5]],
}
experiment_idx = 17
n_runs = 3
agents_17 = train(n_runs, params, PROBLEM, experiment_idx)
# Out:
# {'problem': 'tsp', 'embedding_layers': 4, 'nstep': 1, 'lr_config': [[0, 0.001], [0.7, 0.0001], [0.9, 1e-05]], 'eps_start': 1.0, 'eps_end': 0.05, 'eps_end_at_episode': 0.9, 'n_episodes': 1000, 'validate_each': 100, 'print_train_metrics_each': 10, 'batch_size': 64, 'exact_solution_max_size': 20, 'graph_params': {'max_coord': 1000000.0, 'k_nearest': 10}, 'discount_factor': 0.1, 'graph_type': <GraphType.EUCLIDEAN: 1>, 'n_vertices': 13, 'env_extra_params': {'add_node_anywhere': True}}
# Starting run #1/3...
# Starting run #2/3...
# Starting run #3/3...
# Min of avg validation score across episodes: 1.0485041303897655
# CPU times: user 30min 4s, sys: 4.9 s, total: 30min 8s
# Wall time: 5min 33s

# %%
replay_graphs('tsp', 17, 0.05)
# Out:
# config_parsed="{'problem': 'tsp', 'embedding_layers': 4, 'nstep': 1, 'lr_config': [[0, 0.001], [0.7, 0.0001], [0.9, 1e-05]], 'eps_start': 1.0, 'eps_end': 0.05, 'eps_end_at_episode': 0.9, 'n_episodes': 1000, 'validate_each': 100, 'print_train_metrics_each': 10, 'batch_size': 64, 'exact_solution_max_size': 20, 'graph_params': {'max_coord': 1000000.0, 'k_nearest': 10}, 'discount_factor': 0.1, 'graph_type': 1, 'n_vertices': 13, 'env_extra_params': {'add_node_anywhere': True}}"
# Min of avg validation score across episodes: 1.0485041303897655

# %%
# %%time
params = {
    **tsp_base_params,
    'graph_type': GraphType.EUCLIDEAN,
    'n_vertices': 13,
    'n_episodes': 1000,
    'eps_start': 1.00,
    'eps_end': 0.05,
    'eps_end_at_episode': 0.9,
    'nstep': 1,
    'env_extra_params': {'add_node_anywhere': True},
    'lr_config': [[0, 1e-3], [0.7, 1e-4], [0.9, 1e-5]],
}
experiment_idx = 18
n_runs = 3
agents_18 = train(n_runs, params, PROBLEM, experiment_idx)
# Out:
# {'problem': 'tsp', 'embedding_layers': 4, 'nstep': 1, 'lr_config': [[0, 0.001], [0.7, 0.0001], [0.9, 1e-05]], 'eps_start': 1.0, 'eps_end': 0.05, 'eps_end_at_episode': 0.9, 'n_episodes': 1000, 'validate_each': 100, 'print_train_metrics_each': 10, 'batch_size': 64, 'exact_solution_max_size': 20, 'graph_params': {'max_coord': 1000000.0, 'k_nearest': 10}, 'discount_factor': 0.1, 'graph_type': <GraphType.EUCLIDEAN: 1>, 'n_vertices': 13, 'env_extra_params': {'add_node_anywhere': True}}
# Starting run #1/3...
# Starting run #2/3...
# Starting run #3/3...
# Min of avg validation score across episodes: 1.044059540573295
# CPU times: user 27min 47s, sys: 3.12 s, total: 27min 50s
# Wall time: 4min 50s

# %%
# %%time
params = {
    **tsp_base_params,
    'graph_type': GraphType.EUCLIDEAN,
    'n_vertices': 11,
    'n_episodes': 2000,
    'eps_start': 1.00,
    'eps_end': 0.05,
    'eps_end_at_episode': 0.9,
    'nstep': 1,
    'env_extra_params': {'positive_reward': False},
#     'lr_config': [[0, 1e-3], [0.7, 1e-4], [0.9, 1e-5]],
    'lr_config': [[0, 1e-3]],
}
experiment_idx = 18
n_runs = 3
agents_18 = train(n_runs, params, PROBLEM, experiment_idx)
# Out:
# {'problem': 'tsp', 'embedding_layers': 4, 'nstep': 1, 'lr_config': [[0, 0.001]], 'eps_start': 1.0, 'eps_end': 0.05, 'eps_end_at_episode': 0.9, 'n_episodes': 2000, 'validate_each': 100, 'validate_at_start': True, 'print_train_metrics_each': 10, 'batch_size': 64, 'exact_solution_max_size': 20, 'graph_params': {'max_coord': 1000000.0, 'k_nearest': 10}, 'discount_factor': 0.1, 'graph_type': <GraphType.EUCLIDEAN: 1>, 'n_vertices': 11, 'env_extra_params': {'positive_reward': False}}
# Starting run #1/3...
# Starting run #2/3...
# Starting run #3/3...
# Min of avg validation score across episodes: 1.0424467732173412
# CPU times: user 44min 59s, sys: 2.84 s, total: 45min 1s
# Wall time: 6min 36s

# %%
# %%time
params = {
    **tsp_base_params,
    'graph_type': GraphType.EUCLIDEAN,
    'n_vertices': 11,
    'n_episodes': 2000,
    'eps_start': 1.00,
    'eps_end': 0.05,
    'eps_end_at_episode': 0.9,
    'nstep': 1,
    'env_extra_params': {'positive_reward': True},
#     'lr_config': [[0, 1e-3], [0.7, 1e-4], [0.9, 1e-5]],
    'lr_config': [[0, 1e-3]],
}
experiment_idx = 19
n_runs = 3
agents_19 = train(n_runs, params, PROBLEM, experiment_idx)
# Out:
# {'problem': 'tsp', 'embedding_layers': 4, 'nstep': 1, 'lr_config': [[0, 0.001]], 'eps_start': 1.0, 'eps_end': 0.05, 'eps_end_at_episode': 0.9, 'n_episodes': 2000, 'validate_each': 100, 'validate_at_start': True, 'print_train_metrics_each': 10, 'batch_size': 64, 'exact_solution_max_size': 20, 'graph_params': {'max_coord': 1000000.0, 'k_nearest': 10}, 'discount_factor': 0.1, 'graph_type': <GraphType.EUCLIDEAN: 1>, 'n_vertices': 11, 'env_extra_params': {'positive_reward': True}}
# Starting run #1/3...
# Starting run #2/3...
# Starting run #3/3...
# Min of avg validation score across episodes: 1.0029962595635384
# CPU times: user 46min 13s, sys: 2.78 s, total: 46min 16s
# Wall time: 6min 53s

# %%
# %%time
params = {
    **tsp_base_params,
    'graph_type': GraphType.EUCLIDEAN,
    'n_vertices': 15,
    'n_episodes': 2000,
    'eps_start': 1.00,
    'eps_end': 0.05,
    'eps_end_at_episode': 0.9,
    'nstep': 1,
    'env_extra_params': {'positive_reward': True},
#     'lr_config': [[0, 1e-3], [0.7, 1e-4], [0.9, 1e-5]],
    'lr_config': [[0, 1e-3]],
}
experiment_idx = 20
n_runs = 3
agents_20 = train(n_runs, params, PROBLEM, experiment_idx)
# Out:
# {'problem': 'tsp', 'embedding_layers': 4, 'nstep': 1, 'lr_config': [[0, 0.001]], 'eps_start': 1.0, 'eps_end': 0.05, 'eps_end_at_episode': 0.9, 'n_episodes': 2000, 'validate_each': 100, 'validate_at_start': True, 'print_train_metrics_each': 10, 'batch_size': 64, 'exact_solution_max_size': 20, 'graph_params': {'max_coord': 1000000.0, 'k_nearest': 10}, 'discount_factor': 0.1, 'graph_type': <GraphType.EUCLIDEAN: 1>, 'n_vertices': 15, 'env_extra_params': {'positive_reward': True}}
# Starting run #1/3...
# Starting run #2/3...
# Starting run #3/3...
# Min of avg validation score across episodes: 1.0054553711055194
# CPU times: user 1h 20min 40s, sys: 14.5 s, total: 1h 20min 54s
# Wall time: 22min 22s

# %%
replay_graphs(PROBLEM, 18, 0.05)
# Out:
# config_parsed="{'problem': 'tsp', 'embedding_layers': 4, 'nstep': 1, 'lr_config': [[0, 0.001]], 'eps_start': 1.0, 'eps_end': 0.05, 'eps_end_at_episode': 0.9, 'n_episodes': 1000, 'validate_each': 100, 'validate_at_start': True, 'print_train_metrics_each': 10, 'batch_size': 64, 'exact_solution_max_size': 20, 'graph_params': {'max_coord': 1000000.0, 'k_nearest': 10}, 'discount_factor': 0.1, 'graph_type': 1, 'n_vertices': 11, 'env_extra_params': {'add_node_anywhere': True}}"
# Min of avg validation score across episodes: 1.0317461934724623

# %%
agents_18[0].save_model("")
# Out:
# 3

# %%
import numpy as np
np.zeros((2,0))
# Out:
# array([], shape=(2, 0), dtype=float64)

# %%
import numpy as np
np.array([1,2,3]).unsqueeze(-1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-ed58dc00701e> in <module>
#       1 import numpy as np
# ----> 2 np.array([1,2,3]).unsqueeze(-1)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'unsqueeze'

# %%
np.expand_dims(np.array([1,2]), 1).shape
# Out:
# (2, 1)

# %%
from s2v_dqn.instances.instance_generator import InstanceGenerator
from s2v_dqn.agents.s2v_dqn.dqn_agent import DQNAgent
from s2v_dqn.envs.tsp.tsp_env import TSPEnv
import networkx as nx

# %%
gp = {'k_nearest': 3, 'max_coord': 1}
ig = InstanceGenerator(10, 10, GraphType.EUCLIDEAN, graph_params=gp)
env = TSPEnv(ig, gp)
agent = DQNAgent('tsp')

# %%
g2.nodes[0]
# Out:
# {'coords': array([0.15416284, 0.7400497 ])}

# %%
g,g2 = ig.generate_graph(12)
nx.draw_networkx(g, arrows=True, )

# %%
g,g2 = ig.generate_graph()

# %%
nx.draw_networkx(g2, arrows=True, )

# %%
1.0 * True
# Out:
# 1.0
