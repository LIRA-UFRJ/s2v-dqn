# %%
import sys
sys.path.append("../") # go to parent dir

import re

from s2v_dqn.graph_type import GraphType
from s2v_dqn.interaction import train
from s2v_dqn.utils import replay_graphs

# %load_ext autoreload
# %autoreload 2

# %%
PROBLEM = 'TSP'

# %%
tsp_base_params = {
    # 'embedding_layers': 5,
    'embedding_layers': 3,
    'nstep': 2,
    'lr_config': [[0, 1e-3], [0.5, 1e-4], [0.75, 1e-5]],
    'eps_start': 1.00,
    'eps_end': 0.00,
    'eps_end_at_episode': 1.0,
    'n_episodes': 5000,
    'validate_each': 100,
    'print_train_metrics_each': 10,
    'batch_size': 64,
    'exact_solution_max_size': 20,
    'graph_params': {'max_coord': 1e6, 'k_nearest': 10},
}

# %%
# %%time
params = {
    **tsp_base_params,
    'graph_type': GraphType.EUCLIDEAN,
    'n_vertices': 15,
}
experiment_idx = 1
n_runs = 3
agents = train(n_runs, params, PROBLEM, experiment_idx)
# Out:
# {'problem': 'tsp', 'embedding_layers': 5, 'nstep': 2, 'lr_config': [[0, 0.001], [0.5, 0.0001], [0.75, 1e-05]], 'eps_start': 1.0, 'eps_end': 0.0, 'eps_end_at_episode': 1.0, 'n_episodes': 5000, 'validate_each': 100, 'print_train_metrics_each': 10, 'batch_size': 64, 'exact_solution_max_size': 20, 'graph_params': {'max_coord': 1000000.0}, 'graph_type': <GraphType.EUCLIDEAN: 1>, 'n_vertices': 15}
# Starting run #1/3...
# Starting run #2/3...
# Starting run #3/3...
# Min of avg validation score across episodes: 1.6582611155111433
# CPU times: user 3h 37min 43s, sys: 29 s, total: 3h 38min 12s
# Wall time: 1h 2min 8s

# %%
# %%time
params = {
    **tsp_base_params,
    'graph_type': GraphType.EUCLIDEAN,
    'n_vertices': 10,
}
experiment_idx = 2
n_runs = 3
agents_2 = train(n_runs, params, PROBLEM, experiment_idx)
# Out:
# {'problem': 'tsp', 'embedding_layers': 5, 'nstep': 2, 'lr_config': [[0, 0.001], [0.5, 0.0001], [0.75, 1e-05]], 'eps_start': 1.0, 'eps_end': 0.0, 'eps_end_at_episode': 1.0, 'n_episodes': 5000, 'validate_each': 100, 'print_train_metrics_each': 10, 'batch_size': 64, 'exact_solution_max_size': 20, 'graph_params': {'max_coord': 1000000.0}, 'graph_type': <GraphType.EUCLIDEAN: 1>, 'n_vertices': 10}
# Starting run #1/3...
# Starting run #2/3...
# Starting run #3/3...
# Min of avg validation score across episodes: 1.0913485902598739
# CPU times: user 1h 57min 31s, sys: 4.44 s, total: 1h 57min 36s
# Wall time: 20min 5s

# %%
# %%time
params = {
    **tsp_base_params,
    'graph_type': GraphType.EUCLIDEAN,
    'n_vertices': 10,
    'n_episodes': 5000,
}
experiment_idx = 3
n_runs = 3
agents_3 = train(n_runs, params, PROBLEM, experiment_idx)
# Out:
# {'problem': 'tsp', 'embedding_layers': 5, 'nstep': 2, 'lr_config': [[0, 0.001], [0.5, 0.0001], [0.75, 1e-05]], 'eps_start': 1.0, 'eps_end': 0.0, 'eps_end_at_episode': 1.0, 'n_episodes': 5000, 'validate_each': 100, 'print_train_metrics_each': 10, 'batch_size': 64, 'exact_solution_max_size': 20, 'graph_params': {'max_coord': 1000000.0, 'k_nearest': 10}, 'graph_type': <GraphType.EUCLIDEAN: 1>, 'n_vertices': 10}
# Starting run #1/3...
# Starting run #2/3...
# Starting run #3/3...
# Min of avg validation score across episodes: 1.241090220404019
# CPU times: user 1h 35min 40s, sys: 3.55 s, total: 1h 35min 43s
# Wall time: 13min 36s

# %%
# %%time
params = {
    **tsp_base_params,
    'graph_type': GraphType.EUCLIDEAN,
    'n_vertices': 10,
    'n_episodes': 5000,
}
experiment_idx = 4
n_runs = 3
agents_4 = train(n_runs, params, PROBLEM, experiment_idx)
# Out:
# {'problem': 'tsp', 'embedding_layers': 5, 'nstep': 2, 'lr_config': [[0, 0.001], [0.5, 0.0001], [0.75, 1e-05]], 'eps_start': 1.0, 'eps_end': 0.0, 'eps_end_at_episode': 1.0, 'n_episodes': 5000, 'validate_each': 100, 'print_train_metrics_each': 10, 'batch_size': 64, 'exact_solution_max_size': 20, 'graph_params': {'max_coord': 1000000.0, 'k_nearest': 10}, 'graph_type': <GraphType.EUCLIDEAN: 1>, 'n_vertices': 10}
# Starting run #1/3...
# Starting run #2/3...
# Starting run #3/3...
# Min of avg validation score across episodes: 1.1492949158374322
# CPU times: user 1h 35min 54s, sys: 3.92 s, total: 1h 35min 58s
# Wall time: 13min 36s

# %%
# %%time
params = {
    **tsp_base_params,
    'graph_type': GraphType.EUCLIDEAN,
    'n_vertices': 10,
    'n_episodes': 5000,
}
experiment_idx = 5
n_runs = 3
agents_5 = train(n_runs, params, PROBLEM, experiment_idx)
# Out:
# {'problem': 'tsp', 'embedding_layers': 3, 'nstep': 2, 'lr_config': [[0, 0.001], [0.5, 0.0001], [0.75, 1e-05]], 'eps_start': 1.0, 'eps_end': 0.0, 'eps_end_at_episode': 1.0, 'n_episodes': 5000, 'validate_each': 100, 'print_train_metrics_each': 10, 'batch_size': 64, 'exact_solution_max_size': 20, 'graph_params': {'max_coord': 1000000.0, 'k_nearest': 10}, 'graph_type': <GraphType.EUCLIDEAN: 1>, 'n_vertices': 10}
# Starting run #1/3...
# ---------------------------------------------------------------------------
# SystemExit                                Traceback (most recent call last)
# <timed exec> in <module>
#
# ~/dev/ufrj/msc/tese/tsp/s2v_dqn/interaction.py in train(n_runs, params, problem, experiment_idx)
#     324         print(f'Starting run #{run_idx+1}/{n_runs}...')
#     325         print(f'Starting run #{run_idx+1}/{n_runs}...', file=f_log)
# --> 326         scores, val_scores = run_train(
#     327             agent,
#     328             env,
#
# ...
